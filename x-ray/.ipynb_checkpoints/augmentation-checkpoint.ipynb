# %% [markdown]
# # Import

# %%
import tensorflow as tf
import numpy as np
import cv2 as cv
from tqdm import tqdm
import matplotlib.pyplot as plt
from scipy import ndimage
from sklearn.metrics import confusion_matrix, f1_score, roc_curve, auc, roc_auc_score, classification_report, accuracy_score, silhouette_score

# %%
from tensorflow import keras
from tensorflow.keras.applications.densenet import DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D, Input
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, LearningRateScheduler, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import Adadelta, Adam, SGD, Adagrad
from tensorflow.keras.preprocessing.image import ImageDataGenerator, random_rotation

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
    # Currently, memory growth needs to be the same across GPUs
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
      #  for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpus[0], True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
train_filename = './data/new_mimic_train.tfrecords'
val_filename = './data/new_mimic_val.tfrecords'
test_filename = './data/new_mimic_test.tfrecords'
IMAGE_WIDTH, IMAGE_HEIGHT = 256, 256
BUFFER_SIZE = 1000
BATCH_SIZE = 32
random_seed = 8042

# %%
feature_description = {
    'jpg_bytes': tf.io.FixedLenFeature([], tf.string),
    'race': tf.io.FixedLenFeature([], tf.int64),
    'age': tf.io.FixedLenFeature([], tf.int64),
    'gender': tf.io.FixedLenFeature([], tf.int64),
    'subject_id': tf.io.FixedLenFeature([], tf.int64),
    'Cardiomegaly': tf.io.FixedLenFeature([], tf.float32),
    'Consolidation': tf.io.FixedLenFeature([], tf.float32),
    'Edema': tf.io.FixedLenFeature([], tf.float32),
    'Enlarged Cardiomediastinum': tf.io.FixedLenFeature([], tf.float32),
    'Lung Opacity': tf.io.FixedLenFeature([], tf.float32),
    'Atelectasis': tf.io.FixedLenFeature([], tf.float32),
    'No Finding': tf.io.FixedLenFeature([], tf.float32),
    'Pleural Effusion': tf.io.FixedLenFeature([], tf.float32),
    'Pneumonia': tf.io.FixedLenFeature([], tf.float32),
    'Pneumothorax': tf.io.FixedLenFeature([], tf.float32)
}

label_list = ['Pneumothorax', 'Pneumonia', 'Pleural Effusion', 'No Finding', 'Atelectasis', 'Lung Opacity','Enlarged Cardiomediastinum', 'Edema', 'Consolidation', 'Cardiomegaly']

# %% [markdown]
# # Preprocess

# %%
def apply(img):
    img = tf.image.decode_jpeg(img, channels=3)
    return img

# %%
def _parse(example):
    return tf.io.parse_single_example(example, feature_description)

def read_tfrecord_train(example):
    example = tf.io.parse_single_example(example, feature_description)
    
    img = tf.image.decode_jpeg(example['jpg_bytes'], channels=3)
    img = tf.image.random_brightness(img, 0.2, seed=random_seed)
    img = tf.image.random_contrast(img, 0.8, 1, seed=random_seed)
    labels = [tf.cast(0, tf.int32) if example['No Finding'] == 1 else tf.cast(1, tf.int32)]
    
    return img, labels

def read_tfrecord_val(example):
    example = tf.io.parse_single_example(example, feature_description)
    
    img = tf.image.decode_jpeg(example['jpg_bytes'], channels=3)
    labels = [tf.cast(0, tf.int32) if example['No Finding'] == 1 else tf.cast(1, tf.int32)]
    
    return img, labels

# %%
def load_dataset_train(filename):
    dataset = tf.data.TFRecordDataset(filename)
    # dataset = dataset.map(_parse)
    dataset = dataset.map(read_tfrecord_train, num_parallel_calls = tf.data.experimental.AUTOTUNE)
    dataset = dataset.shuffle(BUFFER_SIZE)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    return dataset

def load_dataset_val(filename):
    dataset = tf.data.TFRecordDataset(filename)
    dataset = dataset.map(read_tfrecord_val, num_parallel_calls = tf.data.experimental.AUTOTUNE)
    dataset = dataset.shuffle(BUFFER_SIZE)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    return dataset

# %%
dataset_train = load_dataset(train_filename)
dataset_val = load_dataset(val_filename)
dataset_test = load_dataset(test_filename)

# %%
plt.figure(figsize=(10, 10))
for img, label in dataset_val.take(1):
    for n in range(32):
        ax = plt.subplot(4, 8, n+1)
        plt.imshow(img[n], cmap='gray')
        plt.axis("off")

# %% [markdown]
# # Model

# %%
input_shape = (IMAGE_WIDTH, IMAGE_HEIGHT, 3)
input_img = Input(input_shape)
x = tf.keras.applications.densenet.preprocess_input(input_img)
base_model = DenseNet121(weights='imagenet', include_top=False, input_tensor = x, pooling = 'avg')
x = base_model(x)
predictions = Dense(1, activation="sigmoid")(x)
model = Model(inputs=input_img, outputs=predictions)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# tf.math.truediv_2 (TFOpLambd (None, 256, 256, 3)       0
# _________________________________________________________________
# tf.nn.bias_add_1 (TFOpLambda (None, 256, 256, 3)       0
# _________________________________________________________________
# tf.math.truediv_3 (TFOpLambd (None, 256, 256, 3)       0
# _________________________________________________________________
# densenet121 (Functional)     (None, 1024)              7037504
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 7,038,529
# Trainable params: 6,954,881
# Non-trainable params: 83,648
# _________________________________________________________________

# %% [markdown]
# # Training

# %%
callbacks_list = [EarlyStopping(monitor='val_loss',patience=10),
                  ModelCheckpoint(filepath='./model/baseline/baseline_aug.h5',monitor='val_loss',save_best_only=True),
                  ReduceLROnPlateau(monitor='val_loss',factor=0.2, patience=3)]
initial_learning_rate = 0.001

# %%
opt = Adam(learning_rate=initial_learning_rate, epsilon=1e-8)
model.compile(optimizer=opt,loss='binary_crossentropy',
metrics=[tf.keras.metrics.AUC(), tf.keras.metrics.BinaryAccuracy()])

# %%
epochs = 30
history = model.fit(
    dataset_train,
    validation_data=dataset_val, 
    epochs=epochs,
    verbose=1,
    callbacks=callbacks_list,
)
# Out:
# Epoch 1/30
# 2029/2029 [==============================] - 652s 318ms/step - loss: 0.3685 - auc_1: 0.9120 - binary_accuracy: 0.8452 - val_loss: 0.5762 - val_auc_1: 0.8374 - val_binary_accuracy: 0.6517
# Epoch 2/30
# 2029/2029 [==============================] - 642s 316ms/step - loss: 0.3324 - auc_1: 0.9277 - binary_accuracy: 0.8664 - val_loss: 0.6589 - val_auc_1: 0.7526 - val_binary_accuracy: 0.6332
# Epoch 3/30
# 2029/2029 [==============================] - 648s 319ms/step - loss: 0.3204 - auc_1: 0.9319 - binary_accuracy: 0.8725 - val_loss: 0.4431 - val_auc_1: 0.9109 - val_binary_accuracy: 0.7655
# Epoch 4/30
# 2029/2029 [==============================] - 648s 319ms/step - loss: 0.3107 - auc_1: 0.9362 - binary_accuracy: 0.8767 - val_loss: 0.7047 - val_auc_1: 0.5444 - val_binary_accuracy: 0.5176
# Epoch 5/30
# 2029/2029 [==============================] - 633s 312ms/step - loss: 0.3022 - auc_1: 0.9392 - binary_accuracy: 0.8804 - val_loss: 0.7393 - val_auc_1: 0.7901 - val_binary_accuracy: 0.5283
# Epoch 6/30
# 2029/2029 [==============================] - 626s 308ms/step - loss: 0.2973 - auc_1: 0.9409 - binary_accuracy: 0.8834 - val_loss: 0.7330 - val_auc_1: 0.7220 - val_binary_accuracy: 0.5473
# Epoch 7/30
# 2029/2029 [==============================] - 625s 308ms/step - loss: 0.2748 - auc_1: 0.9484 - binary_accuracy: 0.8933 - val_loss: 0.5514 - val_auc_1: 0.9078 - val_binary_accuracy: 0.6591
# Epoch 8/30
# 2029/2029 [==============================] - 625s 308ms/step - loss: 0.2619 - auc_1: 0.9527 - binary_accuracy: 0.8991 - val_loss: 0.4877 - val_auc_1: 0.9006 - val_binary_accuracy: 0.7262
# Epoch 9/30
# 2029/2029 [==============================] - 625s 308ms/step - loss: 0.2491 - auc_1: 0.9571 - binary_accuracy: 0.9032 - val_loss: 0.4939 - val_auc_1: 0.8976 - val_binary_accuracy: 0.7383
# Epoch 10/30
# 2029/2029 [==============================] - 625s 308ms/step - loss: 0.2389 - auc_1: 0.9607 - binary_accuracy: 0.9081 - val_loss: 0.3197 - val_auc_1: 0.9346 - val_binary_accuracy: 0.8799
# Epoch 11/30
# 2029/2029 [==============================] - 625s 308ms/step - loss: 0.2293 - auc_1: 0.9635 - binary_accuracy: 0.9115 - val_loss: 0.3250 - val_auc_1: 0.9337 - val_binary_accuracy: 0.8803
# Epoch 12/30
# 2029/2029 [==============================] - 626s 308ms/step - loss: 0.2222 - auc_1: 0.9657 - binary_accuracy: 0.9140 - val_loss: 0.3410 - val_auc_1: 0.9317 - val_binary_accuracy: 0.8739
# Epoch 13/30
# 2029/2029 [==============================] - 626s 309ms/step - loss: 0.2171 - auc_1: 0.9673 - binary_accuracy: 0.9164 - val_loss: 0.3437 - val_auc_1: 0.9299 - val_binary_accuracy: 0.8725
# Epoch 14/30
# 2029/2029 [==============================] - 627s 309ms/step - loss: 0.2125 - auc_1: 0.9686 - binary_accuracy: 0.9185 - val_loss: 0.3359 - val_auc_1: 0.9332 - val_binary_accuracy: 0.8821
# Epoch 15/30
# 2029/2029 [==============================] - 627s 309ms/step - loss: 0.2090 - auc_1: 0.9697 - binary_accuracy: 0.9198 - val_loss: 0.3367 - val_auc_1: 0.9330 - val_binary_accuracy: 0.8825
# Epoch 16/30
# 2029/2029 [==============================] - 626s 309ms/step - loss: 0.2078 - auc_1: 0.9701 - binary_accuracy: 0.9209 - val_loss: 0.3404 - val_auc_1: 0.9327 - val_binary_accuracy: 0.8824
# Epoch 17/30
# 2029/2029 [==============================] - 626s 309ms/step - loss: 0.2062 - auc_1: 0.9706 - binary_accuracy: 0.9203 - val_loss: 0.3367 - val_auc_1: 0.9329 - val_binary_accuracy: 0.8820
# Epoch 18/30
# 2029/2029 [==============================] - 626s 309ms/step - loss: 0.2057 - auc_1: 0.9707 - binary_accuracy: 0.9209 - val_loss: 0.3382 - val_auc_1: 0.9318 - val_binary_accuracy: 0.8806
# Epoch 19/30
# 2029/2029 [==============================] - 626s 309ms/step - loss: 0.2049 - auc_1: 0.9708 - binary_accuracy: 0.9219 - val_loss: 0.3375 - val_auc_1: 0.9322 - val_binary_accuracy: 0.8808
# Epoch 20/30
# 2029/2029 [==============================] - 626s 309ms/step - loss: 0.2040 - auc_1: 0.9710 - binary_accuracy: 0.9217 - val_loss: 0.3373 - val_auc_1: 0.9321 - val_binary_accuracy: 0.8814
